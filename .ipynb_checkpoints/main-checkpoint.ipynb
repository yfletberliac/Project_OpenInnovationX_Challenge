# %%
import logging, gensim, bz2
from gensim import corpora, models, similarities
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from bs4 import BeautifulSoup
import nltk
import re
from nltk.corpus import stopwords
import string
import itertools
exclude = set(string.punctuation)

# %% [markdown]
# ### open test texts

# %%
soup = BeautifulSoup(open("Re-Nutriv Script_Final Translation Template_deadline 20. april-en-da-T.mxliff"), 'lxml')
soup2 = BeautifulSoup(open("Turkish_Basketball_Clubs_Evaluationprogramme15-16_Repucom_150612_Übersetzten-en-tr-T.mxliff"), 'lxml')

# %%
print "The text language source is", soup.file["source-language"]
print "The text language target is", soup.file["target-language"]
# Out:
# The text language source is en
# The text language target is da

# %% [markdown]
# ### what a file looks like

# %%
print soup.prettify()
# Out:
# <html>
#  <body>
#   <xliff m:level="1" m:version="2.0" version="1.2" xmlns="urn:oasis:names:tc:xliff:document:1.2" xmlns:m="http://www.memsource.com/mxlf/2.0">
#    <file datatype="x-undefined" m:file-format="XLS" m:task-id="QD2UhI1HxBsq4axG0" original="Re-Nutriv Script_Final Translation Template_deadline 20. april.xlsx" source-language="en" target-language="da">
#     <group id="0">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:0" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu1" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estée Lauder ID Script for Re-Nutriv Module {b&gt;| Final | 1/9/14&lt;b}
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu2" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Learning Point 1.0 | How Much Do You Know About Re-Nutriv?
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="2">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:2" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu3" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Screen #
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="3">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:3" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu5" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Completion Screen
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="4">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:4" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu6" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        On-screen Text
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="5">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:5" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu6" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        English
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="6">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:6" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu7" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        How Much Do You Know About Re-Nutriv?
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="7">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:7" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu7" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Read each question, select the best choice and then select {b&gt;Submit.&lt;b}
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="8">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:8" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu7" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        [Begin]
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="9">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:9" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        How do you identify a Re-Nutriv customer?
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="10">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:10" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        A. Look at what she's wearing.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="11">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:11" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        B. Assume every customer is a Re-Nutriv customer; introduce it to everyone.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="12">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:12" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        C. Always explain to your customer that we have two skincare lines, Beautiful Skin Solutions and Re-Nutriv; share the benefits of each.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="13">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:13" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        D. Always explain to your customer that we have two skincare lines, Beautiful Skin Solutions and Re-Nutriv; tell her that Re-Nutriv is superior.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="14">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:14" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu8" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        [Submit]
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="15">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:15" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu9" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        That's it!
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="16">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:16" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu9" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Explain that we have two skincare lines, and share the benefits of each one.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="17">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:17" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu10" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        That's not it.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="18">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:18" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu10" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Explain that we have two skincare lines, and share the benefits of each one.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="19">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:19" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu11" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Re-Nutriv combines rare and precious ingredients with the latest scientific advances—to revolutionize the world of skincare.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="20">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:20" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu11" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        A. True
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="21">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:21" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu11" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        B. False
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="22">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:22" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu12" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        That's right!
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="23">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:23" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu12" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estée Lauder created Re-Nutriv by combining precious ingredients with the latest scientific advances.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="24">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:24" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu13" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Which of the following is a true statement about Black Diamond Truffle?
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="25">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:25" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu13" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        A. It's found only in Madagascar.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="26">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:26" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu13" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        B. It was developed in a research lab in Cannes.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="27">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:27" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu13" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        C. It was inspired by a decadent Manhattan restaurant dish.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="28">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:28" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu13" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        D. It's one of the world's rarest and most coveted treasures.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="29">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:29" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu14" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        That's it!
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="30">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:30" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu14" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Black Diamond Truffle is one of the rarest, most coveted treasures in the world.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="31">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:31" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu15" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        That's not it.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="32">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:32" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu15" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Actually, Black Diamond Truffle is one of the rarest, most coveted treasures in the world.
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="33">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:33" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu16" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        There's more to learn on this topic!
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="34">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:34" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu16" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        [Next]
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="35">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:35" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu17" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        On-screen Text
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="36">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:36" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu17" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Language
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="37">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:37" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu19" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Tags
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="38">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:38" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu19" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        English
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="39">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:39" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Beautiful
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="40">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:40" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Beautiful Skin Solutions
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="41">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:41" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Black Diamond
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="42">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:42" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Black Diamond Truffle
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="43">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:43" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        creme
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="44">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:44" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        customer
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="45">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:45" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estee
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="46">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:46" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estée
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="47">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:47" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        heritage
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="48">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:48" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        history
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="49">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:49" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        luxury
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="50">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:50" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        precious
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="51">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:51" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        recipe
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="52">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:52" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        renew
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="53">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:53" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Re-Nutriv
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="54">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:54" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Skin
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="55">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:55" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        skincare
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="56">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:56" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Solutions
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="57">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:57" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Truffle
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="58">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:58" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu20" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        ultimate skincare
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="59">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:59" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu21" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Tags
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="60">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:60" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu21" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Language
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="61">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:61" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu22" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estée Lauder ID Script for Re-Nutriv Module {b&gt;| Final | 1/9/14&lt;b}
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="62">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:62" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu23" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Learning Point 2.0 | The Re-Nutriv Story:
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="63">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:63" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu23" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Then
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="64">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:64" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu24" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Screen #
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="65">
# ...
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1188">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1188" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        dual infusion
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1189">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1189" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        elixir
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1190">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1190" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        energy
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1191">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1191" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Estée
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1192">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1192" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        extract
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1193">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1193" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        gold
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1194">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1194" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        hydrating
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1195">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1195" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        luxury
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1196">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1196" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        precious
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1197">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1197" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        rare beauty
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1198">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1198" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Re-Nutriv
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1199">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1199" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        research
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1200">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1200" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        scent
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1201">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1201" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        South Sea Pearl
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1202">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1202" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        transformative
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1203">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1203" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        truffle
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1204">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1204" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        ultimate diamond
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1205">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1205" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        ultimate skincare
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1206">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1206" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        vitality
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1207">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1207" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu350" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        youth
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1208">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1208" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu351" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Tags
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#     <group id="1209">
#      <context-group>
#       <context context-type="x-file-part">
#        xl/sharedStrings.xml
#       </context>
#      </context-group>
#      <trans-unit id="QD2UhI1HxBsq4axG0:1209" m:confirmed="0" m:created-at="0" m:created-by="" m:gross-score="0.0" m:level-edited="false" m:locked="false" m:modified-at="0" m:modified-by="" m:para-id="2-tu351" m:score="0.0" m:trans-origin="null" xml:space="preserve">
#       <source>
#        Language
#       </source>
#       <target>
#       </target>
#       <alt-trans origin="machine-trans">
#        <target>
#        </target>
#       </alt-trans>
#       <alt-trans origin="memsource-tm">
#        <target>
#        </target>
#       </alt-trans>
#      </trans-unit>
#     </group>
#    </file>
#    <m:extra>
#     <m:users>
#     </m:users>
#    </m:extra>
#   </xliff>
#  </body>
# </html>

# %% [markdown]
# ### targeting the content

# %%
strings=[]
for string in soup.find_all("source"):
    strings.append(string.string)
    
strings2=[]
for string2 in soup2.find_all("source"):
    strings2.append(string2.string)

# %% [markdown]
# ### tokenizing

# %%
tokens=[]
wnl = nltk.WordNetLemmatizer()
tokens.append(nltk.word_tokenize(''.join(w for w in strings)))
tokens = [w for w in tokens[0] if not re.search('\.*[0-9]+\.*', w)]
tokens = [w for w in tokens if w not in exclude]
tokens = [w for w in tokens if len(w) > 2]
tokens = [w.lower() for w in tokens]
tokens = [w for w in tokens if w not in stopwords.words('english')]
tokens = [wnl.lemmatize(t) for t in tokens]

tokens2=[]
wnl = nltk.WordNetLemmatizer()
tokens2.append(nltk.word_tokenize(''.join(w for w in strings2)))
tokens2 = [w for w in tokens2[0] if not re.search('\.*[0-9]+\.*', w)]
tokens2 = [w for w in tokens2 if w not in exclude]
tokens2 = [w for w in tokens2 if len(w) > 2]
tokens2 = [w.lower() for w in tokens2]
tokens2 = [w for w in tokens2 if w not in stopwords.words('english')]
tokens2 = [wnl.lemmatize(t) for t in tokens2]

texts = [tokens] + [tokens2]

# %% [markdown]
# ---------

# %% [markdown]
# ### load lda environement (locally)

# %%
lda = gensim.models.ldamodel.LdaModel.load('/Users/Flet-BerliacYannis/gensim/results/LDA/wikipedia_lda', mmap='r')

# %%
for a in lda.print_topics(10):
    print a
    print "="*30
# Out:
# 0.008*research + 0.008*physics + 0.006*professor + 0.006*science + 0.005*chemistry + 0.005*engineering + 0.004*institute + 0.004*sciences + 0.003*technology + 0.003*laboratory
# ==============================
# 0.024*adelaide + 0.023*alaska + 0.016*barn + 0.013*cdp + 0.012*uav + 0.012*smokehouse + 0.009*fpv + 0.009*kristiansand + 0.008*arctiidae + 0.008*torrens
# ==============================
# 0.012*basketball + 0.011*league + 0.010*coach + 0.009*football + 0.008*player + 0.007*conference + 0.007*tournament + 0.007*game + 0.006*hockey + 0.006*baseball
# ==============================
# 0.064*zealand + 0.045*queensland + 0.031*brisbane + 0.030*rugby + 0.025*auckland + 0.019*rebounds + 0.017*australia + 0.015*campeonato + 0.015*wellington + 0.014*blacks
# ==============================
# 0.020*tbd + 0.008*mississauga + 0.008*ethiopian + 0.007*krishnan + 0.006*ethiopia + 0.006*nollywood + 0.006*kandy + 0.005*addis + 0.005*cif + 0.005*byu
# ==============================
# 0.040*church + 0.012*bishop + 0.010*catholic + 0.009*parish + 0.007*diocese + 0.006*cathedral + 0.005*ordained + 0.005*chapel + 0.005*priest + 0.005*saint
# ==============================
# 0.032*townland + 0.032*kbs + 0.031*mbc + 0.025*sbs + 0.025*portuguese + 0.024*portugal + 0.015*righthanded + 0.012*roubaix + 0.012*thammarat + 0.011*lisbon
# ==============================
# 0.044*polish + 0.033*van + 0.030*dutch + 0.024*poland + 0.019*netherlands + 0.015*amsterdam + 0.015*warsaw + 0.014*swimmers + 0.010*jan + 0.009*hordaland
# ==============================
# 0.040*china + 0.039*chinese + 0.025*hong + 0.024*kong + 0.016*li + 0.014*wang + 0.013*taiwan + 0.013*chen + 0.012*zhang + 0.012*liu
# ==============================
# 0.029*species + 0.013*mm + 0.010*genus + 0.009*grey + 0.009*brown + 0.008*dark + 0.008*described + 0.007*costa + 0.007*gelechiidae + 0.007*pale
# ==============================

# %% [markdown]
# ### indexing the tokens of the corpus

# %%
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %% [markdown]
# ### running lda on corpus

# %%
corpus_lda = lda[corpus]

# %% [markdown]
# ### displaying the major topics

# %%
a=[]
for doc in corpus_lda:
    a.append(sorted(doc, key=lambda item: (-1)*item[1]))

# %%
a
# Out:
# [[(77, 0.048021750264448208),
#   (60, 0.037816028352704437),
#   (97, 0.036066992183691984),
#   (86, 0.034664181390174624),
#   (89, 0.030587296684802496),
#   (61, 0.028138336343056566),
#   (81, 0.025640411790193066),
#   (28, 0.024426121958163568),
#   (39, 0.024341275277887049),
#   (41, 0.024300498364674013),
#   (2, 0.024191702888013453),
#   (73, 0.022617794325753136),
#   (35, 0.022324188779798238),
#   (78, 0.020585232867487712),
#   (85, 0.019676143372090234),
#   (45, 0.01918075162670406),
#   (67, 0.018501335585589807),
#   (33, 0.017870752405816502),
#   (34, 0.015577208700138718),
#   (88, 0.015210049700667784),
#   (48, 0.015168290013777567),
#   (19, 0.014643786356804389),
#   (84, 0.013840591818982124),
#   (47, 0.012876553393209209),
#   (38, 0.012788949363609789),
#   (83, 0.012494387071354656),
#   (23, 0.012475830057111743),
#   (29, 0.012229974228717654),
#   (64, 0.01131396355917668),
#   (25, 0.011272025844061444),
#   (4, 0.010919168964325958),
#   (91, 0.010731250352608333),
#   (75, 0.010680236289427908),
#   (68, 0.010667097380268574),
#   (16, 0.010637905074085675),
#   (94, 0.010521213852372369),
#   (7, 0.01047236686121189),
#   (55, 0.010085174655417507)],
#  [(86, 0.09215865356126389),
#   (89, 0.081892607240493534),
#   (98, 0.032520128660295682),
#   (2, 0.030710019125968113),
#   (94, 0.028731857991078177),
#   (67, 0.028214247803823141),
#   (77, 0.024609741540159203),
#   (43, 0.023302062706190105),
#   (29, 0.023290798394091605),
#   (0, 0.022456626644961491),
#   (30, 0.022101988638693587),
#   (13, 0.021495883337208126),
#   (81, 0.020804456740379687),
#   (55, 0.019813543631824151),
#   (48, 0.018791164596901264),
#   (33, 0.018635374148460379),
#   (32, 0.01786759500026203),
#   (15, 0.017696389123730377),
#   (73, 0.017506423895828255),
#   (35, 0.017246893352848534),
#   (40, 0.016970370839140117),
#   (16, 0.016568736331136008),
#   (96, 0.016359583952451719),
#   (61, 0.016074635307938036),
#   (23, 0.014745923003758604),
#   (97, 0.014722282256959559),
#   (85, 0.013934791993922132),
#   (19, 0.013721905890369134),
#   (24, 0.013686925911918916),
#   (76, 0.013092362843754743),
#   (74, 0.012876985957000941),
#   (14, 0.012276350283695097),
#   (84, 0.01212670066378967),
#   (83, 0.011957109686831391),
#   (25, 0.01167253402122949),
#   (11, 0.011372524307255674),
#   (22, 0.010852614321516862)]]

# %%
print lda.print_topic(77)
print lda.print_topic(60)
print 
print lda.print_topic(57)
print lda.print_topic(78)
# Out:
# 0.004*television + 0.004*films + 0.004*festival + 0.004*tv + 0.004*actor + 0.004*awards + 0.004*directed + 0.004*show + 0.004*award + 0.003*episode
# 0.014*gk + 0.012*vfl + 0.008*tba + 0.007*hee + 0.007*melbourne + 0.006*eun + 0.006*prem + 0.006*geelong + 0.005*victorian + 0.005*kyung
#
# 0.026*station + 0.024*railway + 0.009*airport + 0.008*train + 0.008*route + 0.007*road + 0.006*rail + 0.006*highway + 0.006*bus + 0.006*junction
# 0.009*fuscous + 0.005*ochreous + 0.005*hindwings + 0.003*plot + 0.003*story + 0.002*novel + 0.002*man + 0.002*suffused + 0.002*love + 0.002*you

# %%
d={}
for w in tokens:
    d[w]=tokens.count(w)
    
d2={}
for w in tokens2:
    d2[w]=tokens2.count(w)

# %%
remove=[]
for u,v in d.iteritems():
    if v==1:
        remove.append(u)
        
remove2=[]
for u,v in d2.iteritems():
    if v==1:
        remove2.append(u)

# %%
liste = [w for w in tokens if w not in remove]
liste2 = [w for w in tokens2 if w not in remove2]

# %% [markdown]
# ### collocations

# %%
mots = ' '.join(liste)
mots2 = ' '.join(liste2)

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
tokens = nltk.wordpunct_tokenize(mots)
finder = BigramCollocationFinder.from_words(tokens)
finder.apply_freq_filter(4)
finder.nbest(bigram_measures.pmi, 20)
# Out:
# [(u'citrus', u'note'),
#  (u'floral', u'scent'),
#  (u'green', u'citrus'),
#  (u'herbaceous', u'floral'),
#  (u'jasmine', u'rose'),
#  (u'lemon', u'grapefruit'),
#  (u'muguet', u'jasmine'),
#  (u'note', u'lemon'),
#  (u'optimal', u'potency'),
#  (u'preserve', u'optimal'),
#  (u'recipe', u'kept'),
#  (u'fresh', u'green'),
#  (u'freshly', u'activated'),
#  (u'potency', u'freshly'),
#  (u'response', u'shown'),
#  (u'secret', u'family'),
#  (u'try', u'sorry'),
#  (u'calm', u'soothe'),
#  (u'consider', u'going'),
#  (u'multiple', u'thing')]

# %%
bigram_measures2 = nltk.collocations.BigramAssocMeasures()
tokens2 = nltk.wordpunct_tokenize(mots2)
finder2 = BigramCollocationFinder.from_words(tokens2)
finder2.apply_freq_filter(4)
finder2.nbest(bigram_measures2.pmi, 20)
# Out:
# [(u'basketbol', u'ligi'),
#  (u'right', u'holder'),
#  (u'repucom', u'june'),
#  (u'coverage', u'audience'),
#  (u'sponsorship', u'evaluation'),
#  (u'medium', u'evaluation'),
#  (u'medium', u'value'),
#  (u'sponsorship', u'value'),
#  (u'value', u'medium')]

# %%
len(mots)
# Out:
# 16533

# %%
len(mots2)
# Out:
# 3472

# %% [markdown]
# - rules (constraint words)
# - contract/law (specific)
# - report
# collocations
# confusion matrix
# tf-idf
