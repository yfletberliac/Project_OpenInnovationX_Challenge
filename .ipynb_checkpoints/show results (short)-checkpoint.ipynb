# %% [markdown]
# # dashboard

# %%
import random
import matplotlib
from lightning import Lightning
matplotlib.rcParams['figure.figsize'] = (18.0, 12.0)
% matplotlib inline

# %%
import izi
reload(izi)
import pickle

# %%
lgn = Lightning(ipython=True, host='https://desolate-castle-4773.herokuapp.com/')
lgn.set_size(size='large')
# Out:
# <div style='margin-top:8px'><img src='data:image/png;base64,...' width='30px' height='35px' style='display: inline-block; padding-right: 10px'></img><span>Lightning initialized</span></div>
# Connected to server at https://desolate-castle-4773.herokuapp.com

# %% [markdown]
# # get filenames & load pre-built data

# %%
filelist = izi.getFileList(u"all_source_texts/")
print "%s files" %len(filelist)
# Out:
# 195 files

# %%
path = random.choice(filelist)

# %%
print path
izi.displayResults(path)
# Out:
# all_source_texts/Vecka 32-1 (29-80)-en-nb_no-T.mxliff
# stats
# number of words 3118
# number of sentences 194
# uniques words: 564
# Difficulty 35.29 / 100
# Average sentiment 5.62380402225 (negative: 0, neutral: 5, positive: 10)
#
# topic distribution
# difficulty over the text
